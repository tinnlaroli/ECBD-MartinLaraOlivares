# %%
import pandas as pd

# %%
import random

# %%
#crear un data frame con 1,000,000 de registros
cantidad = 1000000

# %%
influencer = ["luisito", "vegetta", "sof", "emmaPR", "cheinbaum", "montoya", "el wey del pan", "Diego"]

# likes = random.randint(1000,10000000)

comentarios = ["wow" , "🌴🌴🌴" ,"que bonito" ,"gpi" ,"gpi" ,"mi bello cancun" ,"estan funando a jd" ,"bot bot", "es  ia", "hater #1" , "primer comentario", "<3"]

# fecha = random.randint(2024,2026)

tipo_post = ["foto", "video", "tag", "share"]

# %%
# creacion del DataFrame

dfMillon = pd.DataFrame({
	"influencer" : [ random.choice(influencer) for _ in range(cantidad)],
	"likes" : [ random.randint(1000,10000000) for _ in range(cantidad)],
	"comentarios" : [ random.choice(comentarios) for _ in range(cantidad)],
	"fecha" : [ random.randint(2024,2026) for _ in range(cantidad)],
	"tipo_post" : [ random.choice(tipo_post) for _ in range(cantidad)]
})

# %%
# ???
dfMillon.shape
# Out:
# (1000000, 5)

# %%
#para ver q tipo de dato lo definio
dfMillon.dtypes
# Out:
# influencer       str
# likes          int64
# comentarios      str
# fecha          int64
# tipo_post        str
# dtype: object

# %%
# para ver el peso de todo el dataset en mb
dfMillon.memory_usage(deep=True).sum()/1024**2
# Out:
# np.float64(199.71239471435547)

# %%
df = pd.DataFrame(dfMillon)

# %%
print(df)
# Out:
#             influencer    likes         comentarios  fecha tipo_post
# 0              luisito  2767866                 🌴🌴🌴   2025     share
# 1              vegetta  3747811                  <3   2024     video
# 2              luisito  4109437   primer comentario   2025       tag
# 3                Diego  2423728  estan funando a jd   2024       tag
# 4              vegetta  3175967              es  ia   2024       tag
# ...                ...      ...                 ...    ...       ...
# 999995  el wey del pan  7630671                 wow   2026       tag
# 999996  el wey del pan  7471714          que bonito   2026      foto
# 999997         montoya  1751370                 gpi   2025     share
# 999998         luisito  7289155                 gpi   2024     video
# 999999         luisito  4250537          que bonito   2025     video
#
# [1000000 rows x 5 columns]

# %%
dfMillon['influencer'].nunique()
# Out:
# 8
